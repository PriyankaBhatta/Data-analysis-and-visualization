# %% [markdown]
# # My Jupyter Notebook on IBM Watson Studio

# %% [markdown]
# # PRIYANKA BHATTA
# My desired occupation is data scientist as of now.

# %% [markdown]
# *I am interested in data science because the whole idea of finding data, cleaning it, manipulating it and visualizing it seems intreguing to me. It's so fun to play around with data and with the thought of that in my mind, I said to myself why not do it for a living? This is why I am very much fasciated by data science, it makes me curious all the time which makes me learn about it more and more.*

# %% [markdown]
# ### My code is supoosed to display an output which is a mathematical equation and a print statement.

# %%
print("Hello everyone, have a wonderful day.")
23+23
# Out:
# Hello everyone, have a wonderful day.
# 46

# %% [markdown]
# ### This is example of bulleted list.
# - Main bullet point
#      - Sub bullet point
#
# ### This is example of numbered list.
# 1. Data science
# 1. Artificial Intelligence
#
# ### For image:
# ![cat.jpg](attachment:cat.jpg)
